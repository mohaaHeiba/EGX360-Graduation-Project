# %% [markdown]
# # EGX360 — THE DEEP QUANT MODEL Accuracy 89
# ### Enhancing Down-Trend Detection & Bias Control in the Egyptian Stock Exchange

# %% [markdown]
# ## 1. Environment Setup & Initialization

# %%
import tensorflow as tf
gpu_devices = tf.config.list_physical_devices('GPU')
if gpu_devices:
    print(f"Success! GPU found: {gpu_devices}")
else:
    print("Still not working. Check PATH or CUDA version.")
# Out:
# 2026-03-12 23:20:48.223332: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-12 23:20:48.227200: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-12 23:20:48.556235: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-03-12 23:20:52.288748: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-12 23:20:52.289877: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# Still not working. Check PATH or CUDA version.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773350456.408422   17223 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1773350456.553746   17223 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import lightgbm as lgb
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import StackingClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import joblib
import warnings
warnings.filterwarnings('ignore')
import os

# %% [markdown]
# ## 2. Data Loading & Raw Market Visualization
# We begin by loading the preprocessed EGX30 daily data. Financial time series data is notoriously noisy. Visualizing the raw candlesticks demonstrates why predicting raw daily closing prices is ineffective; the high volatility creates market noise that confuses standard predictive models.

# %%
print("🚀 Loading Final Dataset (EGX + USD + Gold)...")
current_dir = os.getcwd()

# 1. قراءة الملف اللي فيه الذهب والدولار
file_path = os.path.join(current_dir, "data", "EGX30_Final_v9.csv")
df = pd.read_csv(file_path)
df['timestamp'] = pd.to_datetime(df['timestamp']).dt.tz_localize(None).dt.normalize()
df.set_index('timestamp', inplace=True)
# Out:
# 🚀 Loading Final Dataset (EGX + USD + Gold)...

# %%
ir_path = os.path.join(current_dir, "data", "cbe_interest_rate.csv")
if os.path.exists(ir_path):
    ir_df = pd.read_csv(ir_path)
    ir_df['Date'] = pd.to_datetime(ir_df['Date']).dt.normalize()
    ir_df.set_index('Date', inplace=True)
    df = df.join(ir_df, how='left')
    df['Interest_Rate'] = df['Interest_Rate'].ffill().bfill()
    df['IR_Change'] = df['Interest_Rate'].diff().fillna(0)
    print("Interest Rates Merged.")

print(f"Final Shape: {df.shape}")
# Out:
# Interest Rates Merged.
# Final Shape: (6882, 16)

# %%
print(f"Missing values: {df.isnull().sum()}")
df.dropna(inplace=True)
df.sort_index(inplace=True)
# Out:
# Missing values: open                  0
# high                  0
# low                   0
# close                 0
# volume                0
# usd_egp_rate          0
# close_usd             0
# log_ret_usd           1
# price_velocity_usd    2
# gold_usd              0
# gold_egp              0
# gold_log_ret          1
# gold_velocity         2
# gold_ret_lag1         2
# Interest_Rate         0
# IR_Change             0
# dtype: int64

# %%
df.head()
# Out:
#                   open        high         low       close  volume  \
# timestamp
# 1998-01-05  998.390015  998.390015  996.250000  996.250000       0
# 1998-01-06  996.250000  996.250000  992.869995  992.869995       0
# 1998-01-07  992.869995  992.869995  989.349976  989.349976       0
# 1998-01-08  989.349976  989.349976  984.380005  984.380005       0
# 1998-01-11  984.380005  984.380005  980.630005  980.630005       0
#
#             usd_egp_rate   close_usd  log_ret_usd  price_velocity_usd  \
# timestamp
# 1998-01-05        3.8743  257.143226    -0.002146           -0.000285
# 1998-01-06        3.8743  256.270809    -0.003398           -0.001253
# 1998-01-07        3.8743  255.362252    -0.003552           -0.000153
# 1998-01-08        3.8743  254.079448    -0.005036           -0.001485
# 1998-01-11        3.8743  253.111531    -0.003817            0.001219
#
#               gold_usd     gold_egp  gold_log_ret  gold_velocity  \
# timestamp
# 1998-01-05  273.899994  1061.170747           0.0            0.0
# 1998-01-06  273.899994  1061.170747           0.0            0.0
# 1998-01-07  273.899994  1061.170747           0.0            0.0
# 1998-01-08  273.899994  1061.170747           0.0            0.0
# 1998-01-11  273.899994  1061.170747           0.0            0.0
#
#             gold_ret_lag1  Interest_Rate  IR_Change
# timestamp
# 1998-01-05            0.0            9.0        0.0
# 1998-01-06            0.0            9.0        0.0
# 1998-01-07            0.0            9.0        0.0
# 1998-01-08            0.0            9.0        0.0
# 1998-01-11            0.0            9.0        0.0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 6880 entries, 1998-01-05 to 2026-03-09
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   open                6880 non-null   float64
#  1   high                6880 non-null   float64
#  2   low                 6880 non-null   float64
#  3   close               6880 non-null   float64
#  4   volume              6880 non-null   int64
#  5   usd_egp_rate        6880 non-null   float64
#  6   close_usd           6880 non-null   float64
#  7   log_ret_usd         6880 non-null   float64
#  8   price_velocity_usd  6880 non-null   float64
#  9   gold_usd            6880 non-null   float64
#  10  gold_egp            6880 non-null   float64
#  11  gold_log_ret        6880 non-null   float64
#  12  gold_velocity       6880 non-null   float64
#  13  gold_ret_lag1       6880 non-null   float64
#  14  Interest_Rate       6880 non-null   float64
#  15  IR_Change           6880 non-null   float64
# dtypes: float64(15), int64(1)
# memory usage: 913.8 KB

# %%
df.describe()
# Out:
#                open          high           low         close        volume  \
# count   6880.000000   6880.000000   6880.000000   6880.000000  6.880000e+03
# mean    9003.589747   9075.819682   8942.511278   9007.829769  8.944699e+07
# std     8713.183094   8789.313898   8650.186161   8719.512202  1.087450e+08
# min      445.529999    448.019989    445.529999    445.529999  0.000000e+00
# 25%     2527.439941   2546.924927   2519.437500   2531.282532  0.000000e+00
# 50%     6854.725100   6896.870099   6820.724871   6852.655050  6.447120e+07
# 75%    11454.725000  11537.250000  11395.082763  11458.000000  1.407528e+08
# max    52278.100000  52821.700000  51833.800000  52308.300000  8.092790e+08
#
#        usd_egp_rate    close_usd  log_ret_usd  price_velocity_usd  \
# count   6880.000000  6880.000000  6880.000000         6880.000000
# mean      12.277869   735.404065     0.000184           -0.000003
# std       12.057814   414.877585     0.019084            0.025894
# min        3.874300    88.711659    -0.497058           -0.556478
# 25%        5.500450   408.786660    -0.007538           -0.011257
# 50%        6.129850   748.294343     0.000629           -0.000095
# 75%       16.090000   941.076283     0.008975            0.011116
# max       51.631802  2242.408903     0.183692            0.472133
#
#           gold_usd       gold_egp  gold_log_ret  gold_velocity  gold_ret_lag1  \
# count  6880.000000    6880.000000   6880.000000    6880.000000    6880.000000
# mean   1179.569316   22655.747780      0.000799       0.000002       0.000796
# std     815.048775   40714.994644      0.015474       0.022112       0.015473
# min     255.100006     988.333954     -0.133111      -0.476301      -0.133111
# 25%     424.000000    2507.274479     -0.002655      -0.008289      -0.002655
# 50%    1208.350037    8714.175536      0.000000       0.000000       0.000000
# 75%    1640.599976   23261.747688      0.004558       0.007765       0.004524
# max    5301.600098  258295.949091      0.530989       0.530989       0.530989
#
#        Interest_Rate    IR_Change
# count    6880.000000  6880.000000
# mean       11.392987     0.001453
# std         4.820171     0.150282
# min         8.250000    -3.000000
# 25%         9.000000     0.000000
# 50%         9.000000     0.000000
# 75%        11.250000     0.000000
# max        27.250000     8.000000

# %%
sample_df = df.tail(150)
fig_raw = go.Figure(data=[go.Candlestick(x=sample_df.index, 
                open=sample_df['open'],
                high=sample_df['high'],
                low=sample_df['low'],
                close=sample_df['close'])])

# %% [markdown]
# ## 3. Advanced Feature Engineering (The Quant Indicators)
# To make the data machine-readable, we engineer quantitative features. We translate raw price action into mathematical signals representing Trend, Momentum, and Volatility.
#
# ### A. Log Returns & Price Velocity
# **Concept:** Absolute price changes are not statistically comparable over time. Logarithmic returns stabilize the variance. **Price Velocity** (the derivative of log returns) acts as an early warning system for market crashes.
#
# **Mathematical Formula:**
# $$R_t = \ln\left(\frac{P_t + \epsilon}{P_{t-1} + \epsilon}\right)$$
# $$V_t = R_t - R_{t-1}$$

# %% [markdown]
# ### Log Returns & Momentum Acceleration (Epsilon added to prevent Infinity)

# %%
df['log_ret'] = np.log((df['close'] + 1e-6) / (df['close'].shift(1) + 1e-6))

# --- التعديل الجديد: خصائص الدولار ---
# نتأكد إن العواميد دي موجودة، ولو موجودة نحسب الـ log return بالدولار وسرعة السعر
if 'close_usd' in df.columns:
    df['log_ret_usd'] = np.log((df['close_usd'] + 1e-6) / (df['close_usd'].shift(1) + 1e-6))
    df['price_velocity_usd'] = df['log_ret_usd'].diff()
    # ممكن كمان نعمل lag (تأخير) للـ return بالدولار 
    df['log_ret_usd_lag1'] = df['log_ret_usd'].shift(1)
else:
    print("Warning: 'close_usd' not found. Make sure you are using the updated CSV.")
# --------------------------------------# حساب متوسط الفوليوم لآخر 50 يوم
df['Volume_SMA_50'] = df['volume'].rolling(window=50).mean()

# حساب الـ Relative Volume (RVOL)
# بنزود 1e-9 في المقام عشان نتجنب مشكلة القسمة على صفر (خصوصاً في الداتا القديمة جداً)
df['RVOL_50'] = df['volume'] / (df['Volume_SMA_50'] + 1e-9)

# اختياري: ممكن نعمل Clipping للقيم الشاذة جداً عشان الموديل ميتخدعش في أيام الانفجارات السعرية
df['RVOL_50'] = df['RVOL_50'].clip(upper=5.0) # لو الفوليوم زاد عن 5 أضعاف المتوسط، هنعتبره 5 بس

# %% [markdown]
# ### Price Velocity

# %%
df['price_velocity'] = df['log_ret'].diff()

# %% [markdown]
# ### B. Cyclic Time Features
# **Concept:** Tree-based models do not intuitively understand weekly cycles. By mapping days to continuous sine and cosine waves, the model captures the "Day-of-the-Week" effect and institutional trading behaviors.
#
# **Mathematical Formula:**
# $$X_{sin} = \sin\left(\frac{2\pi \cdot d}{7}\right), \quad X_{cos} = \cos\left(\frac{2\pi \cdot d}{7}\right)$$

# %% [markdown]
# ### Cyclic Time Features

# %%
# Cyclic Time Features
df['day_sin'] = np.sin(2 * np.pi * df.index.dayofweek / 7)  # <-- التعديل هنا
df['day_cos'] = np.cos(2 * np.pi * df.index.dayofweek / 7)  # <-- التعديل هنا

# %% [markdown]
# ### C. Exponential Moving Averages (EMA) & Gap Analysis
# **Concept:** The EMA assigns exponentially greater weight to recent prices, making it highly responsive to new trends. We quantify over-extensions by measuring the percentage distance between the current price and the EMA.
#
# **Mathematical Formula:**
# $$EMA_t = \left( P_t \times \alpha \right) + \left( EMA_{t-1} \times (1 - \alpha) \right)$$

# %% [markdown]
# ### The Winning EMAs & Trend Sensors

# %%
for period in [9, 21, 50]:
    ema_col = f'EMA_{period}'
    df[ema_col] = df['close'].ewm(span=period).mean()
    df[f'dist_EMA_{period}'] = (df['close'] - df[ema_col]) / (df[ema_col] + 1e-9)

# %% [markdown]
# ### Critical Downtrend Sensor: Binary flag if price breaks below the fast EMA

# %%
df['below_EMA9'] = (df['close'] < df['EMA_9']).astype(int)

# %% [markdown]
# ### D. Momentum & Panic Detectors (RSI, MACD, Bollinger Bands)
# **Concept:** * **RSI & RSI_diff:** Measures buying/selling exhaustion.
# * **Bollinger Band Width ($BB_{width}$):** Measures market "squeeze". Narrow bands mathematically precede explosive market volatility.

# %% [markdown]
# ### Momentum (RSI & MACD)

# %%
delta = df['close'].diff()
gain = delta.where(delta > 0, 0).rolling(14).mean()
loss = (-delta.where(delta < 0, 0)).rolling(14).mean()
df['RSI'] = 100 - (100 / (1 + gain/(loss + 1e-9)))
df['RSI_diff'] = df['RSI'].diff()

# %%
macd = df['close'].ewm(span=12).mean() - df['close'].ewm(span=26).mean()
df['MACD_Hist'] = macd - macd.ewm(span=9).mean()

# %% [markdown]
# ### Volatility (ATR)

# %%
tr = pd.concat([df['high'] - df['low'], 
                np.abs(df['high'] - df['close'].shift()), 
                np.abs(df['low'] - df['close'].shift())], axis=1).max(axis=1)
df['ATR_pct'] = tr.rolling(14).mean() / (df['close'] + 1e-9)

# %% [markdown]
# ### Panic Detectors (Stochastic & Bollinger Bands)

# %%
low_14 = df['low'].rolling(14).min()
high_14 = df['high'].rolling(14).max()
df['Stoch_K'] = 100 * ((df['close'] - low_14) / (high_14 - low_14 + 1e-9))

# %%
ma20 = df['close'].rolling(20).mean()
std20 = df['close'].rolling(20).std()
df['BB_Width'] = (std20 * 4) / (ma20 + 1e-9)

# %% [markdown]
# ### Temporal Lags

# %%
df['log_ret_lag1'] = df['log_ret'].shift(1)
df['RSI_lag1'] = df['RSI'].shift(1)

# %% [markdown]
# ## 4. Visualizing the Quant Transformation

# %% [markdown]
# ### Base Price Candlesticks

# %%
sample_df = df.tail(150)
fig_quant = go.Figure()

fig_quant.add_trace(go.Candlestick(x=sample_df.index,  # <-- التعديل هنا
                open=sample_df['open'], high=sample_df['high'],
                low=sample_df['low'], close=sample_df['close'], name='Price'))

# %% [markdown]
# ### Adding all features

# %%
fig_quant.update_layout(title='Translating Noise into Mathematical Signals (EMAs & Volatility Bounds)', 
                        yaxis_title='Price (EGP)',
                        xaxis_rangeslider_visible=False,
                        template='plotly_white')
fig_quant.show()

# %% [markdown]
# ## 5. Target Engineering & Data Cleaning
# **Concept:** Predicting raw daily closing prices essentially models a Random Walk. By setting the target as the future direction of the $EMA_{10}$, we train the model to predict the *underlying trend mechanics*, pushing accuracy beyond 80%.
#
# **Mathematical Formula for Target:**
# $$Target = \begin{cases} 1 & \text{if } EMA_{10}(P_{t+1}) > EMA_{10}(P_t) \\ 0 & \text{otherwise} \end{cases}$$

# %% [markdown]
# ### Target: Will the EMA rise tomorrow?

# %%
df['Target'] = (df['close'].ewm(span=10).mean().shift(-1) > df['close'].ewm(span=10).mean()).astype(int)

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)

# %%
final_features = [
    'log_ret', 'log_ret_usd', 'price_velocity', 'price_velocity_usd', 'RVOL_50', 
    'day_sin', 'day_cos', 
    'dist_EMA_9', 'dist_EMA_21', 'dist_EMA_50', 
    'RSI', 'MACD_Hist', 
    'Interest_Rate', 'IR_Change',
    'gold_log_ret', 'gold_velocity', 'gold_ret_lag1' # خصائص الذهب اللي في ملفك
]
X = df[final_features].values
y = df['Target'].values

# %% [markdown]
# ## 6. Machine Learning: Splitting, Scaling & Stacking Ensemble
# **Concept:** We use a chronological split (80/20) to prevent future data leakage. We then utilize an Ensemble Stacking algorithm. Because financial datasets exhibit an inherent upward bias, the Logistic Regression meta-learner applies a 50% higher penalty for missing a "Down-Trend" (`class_weight={0: 1.5}`). This strict risk management dramatically improves the Recall for market crashes.

# %% [markdown]
# ### Train/Test Split (Chronological)

# %%
split = int(len(X) * 0.80)
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %% [markdown]
# ### Scaling

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
# joblib.dump(scaler, "egx360_scaler_quant.pkl")

# %% [markdown]
# ### Stacking Ensemble

# %%
import optuna
from sklearn.model_selection import cross_val_score

# ==========================================
# 1. Optuna: XGBoost Hyperparameter Tuning
# ==========================================
def objective_xgb(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 200, 1500),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.1, log=True),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 0, 5), # لمنع الحفظ الزائد نسبياً
        'random_state': 42,
        'n_jobs': -1
    }
    model = xgb.XGBClassifier(**params)
    # هنختبر الموديل 5 مرات على بيانات التدريب عشان نضمن إنه بيتعلم بجد
    score = cross_val_score(model, X_train_scaled, y_train, cv=5, scoring='accuracy').mean()
    return score

print("🚀 Starting Optuna Tuning for XGBoost...")
study_xgb = optuna.create_study(direction='maximize')
# تقدر تزود n_trials لـ 100 لو جهازك سريع عشان يجيب دقة أعلى
study_xgb.optimize(objective_xgb, n_trials=100) 
best_xgb_params = study_xgb.best_params
print(f"✅ Best XGBoost Params: {best_xgb_params}")

# ==========================================
# 2. Optuna: LightGBM Hyperparameter Tuning
# ==========================================
def objective_lgb(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 200, 1500),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.1, log=True),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'num_leaves': trial.suggest_int('num_leaves', 20, 150),
        'random_state': 42,
        'n_jobs': -1,
        'verbose': -1
    }
    model = lgb.LGBMClassifier(**params)
    score = cross_val_score(model, X_train_scaled, y_train, cv=5, scoring='accuracy').mean()
    return score

print("\n🚀 Starting Optuna Tuning for LightGBM...")
study_lgb = optuna.create_study(direction='maximize')
study_lgb.optimize(objective_lgb, n_trials=100)
best_lgb_params = study_lgb.best_params
print(f"✅ Best LightGBM Params: {best_lgb_params}")

# ==========================================
# 3. بناء الموديل النهائي (Stacking) بالمعاملات الجديدة
# ==========================================
print("\n⚙️ Training Final Stacked Model...")
best_xgb = xgb.XGBClassifier(**best_xgb_params, random_state=42, n_jobs=-1)
best_lgb = lgb.LGBMClassifier(**best_lgb_params, random_state=42, n_jobs=-1, verbose=-1)

base_models = [
    ('xgb', best_xgb),
    ('lgbm', best_lgb)
]

# لغينا الـ Penalty العنيفة بتاعت الهبوط (class_weight) عشان نرفع الـ Accuracy العامة للـ 90%
final_logic = LogisticRegression(C=1.0)
# stack_model = StackingClassifier(estimators=base_models, final_estimator=final_logic, cv=5)

# stack_model.fit(X_train_scaled, y_train)
# Out:
# [I 2026-03-12 23:20:58,283] A new study created in memory with name: no-name-1a0c1820-3520-4843-8571-c017efed7226
# 🚀 Starting Optuna Tuning for XGBoost...
# [I 2026-03-12 23:21:06,001] Trial 0 finished with value: 0.8400430310768829 and parameters: {'n_estimators': 262, 'max_depth': 8, 'learning_rate': 0.07287301052021122, 'subsample': 0.9725612516326281, 'colsample_bytree': 0.9248047325250113, 'gamma': 0.3962366372600695}. Best is trial 0 with value: 0.8400430310768829.
# [I 2026-03-12 23:21:18,234] Trial 1 finished with value: 0.8490130333222738 and parameters: {'n_estimators': 957, 'max_depth': 12, 'learning_rate': 0.04087814978516831, 'subsample': 0.9170468061458023, 'colsample_bytree': 0.582376403453895, 'gamma': 2.3373384370877504}. Best is trial 1 with value: 0.8490130333222738.
# [I 2026-03-12 23:21:28,117] Trial 2 finished with value: 0.8459009883072097 and parameters: {'n_estimators': 711, 'max_depth': 8, 'learning_rate': 0.055125353807833094, 'subsample': 0.9057329228327684, 'colsample_bytree': 0.7806783112997729, 'gamma': 1.9972356221678926}. Best is trial 1 with value: 0.8490130333222738.
# [I 2026-03-12 23:21:39,657] Trial 3 finished with value: 0.8376650948929081 and parameters: {'n_estimators': 978, 'max_depth': 12, 'learning_rate': 0.0918308166486297, 'subsample': 0.7410519064411842, 'colsample_bytree': 0.5106475655224294, 'gamma': 1.9458373234380721}. Best is trial 1 with value: 0.8490130333222738.
# [I 2026-03-12 23:21:51,559] Trial 4 finished with value: 0.8360160729785615 and parameters: {'n_estimators': 971, 'max_depth': 5, 'learning_rate': 0.031836149361469515, 'subsample': 0.8968121628579346, 'colsample_bytree': 0.784075403102785, 'gamma': 0.11670600263303466}. Best is trial 1 with value: 0.8490130333222738.
# [I 2026-03-12 23:21:56,057] Trial 5 finished with value: 0.8539533964053634 and parameters: {'n_estimators': 303, 'max_depth': 12, 'learning_rate': 0.009354965952619483, 'subsample': 0.9283345714294142, 'colsample_bytree': 0.5712547729525999, 'gamma': 3.6234152232537347}. Best is trial 5 with value: 0.8539533964053634.
# [I 2026-03-12 23:22:02,580] Trial 6 finished with value: 0.8504760564229915 and parameters: {'n_estimators': 399, 'max_depth': 7, 'learning_rate': 0.019292606645059943, 'subsample': 0.7247182230139217, 'colsample_bytree': 0.8035593871284277, 'gamma': 4.134209220022972}. Best is trial 5 with value: 0.8539533964053634.
# [I 2026-03-12 23:22:34,428] Trial 7 finished with value: 0.8470000569726096 and parameters: {'n_estimators': 809, 'max_depth': 12, 'learning_rate': 0.010584551987249904, 'subsample': 0.9733002015235166, 'colsample_bytree': 0.90877213894042, 'gamma': 1.2733223864807157}. Best is trial 5 with value: 0.8539533964053634.
# [I 2026-03-12 23:22:40,524] Trial 8 finished with value: 0.8497441259563858 and parameters: {'n_estimators': 676, 'max_depth': 4, 'learning_rate': 0.012489359170073249, 'subsample': 0.8590357113091762, 'colsample_bytree': 0.7540948430931764, 'gamma': 0.08206602638686555}. Best is trial 5 with value: 0.8539533964053634.
# [I 2026-03-12 23:22:58,296] Trial 9 finished with value: 0.8469985488741207 and parameters: {'n_estimators': 1315, 'max_depth': 4, 'learning_rate': 0.007201766515390601, 'subsample': 0.8129659158309983, 'colsample_bytree': 0.9886545781490452, 'gamma': 1.0504996549169836}. Best is trial 5 with value: 0.8539533964053634.
# [I 2026-03-12 23:23:07,853] Trial 10 finished with value: 0.8557833901383765 and parameters: {'n_estimators': 460, 'max_depth': 10, 'learning_rate': 0.00513470167401783, 'subsample': 0.5754111573942229, 'colsample_bytree': 0.6422286570774238, 'gamma': 3.9652659712976877}. Best is trial 10 with value: 0.8557833901383765.
# [I 2026-03-12 23:23:15,246] Trial 11 finished with value: 0.8552347774214196 and parameters: {'n_estimators': 446, 'max_depth': 9, 'learning_rate': 0.005899047153273691, 'subsample': 0.5551415524583134, 'colsample_bytree': 0.6410382480738724, 'gamma': 3.86119391214568}. Best is trial 10 with value: 0.8557833901383765.
# [I 2026-03-12 23:23:22,849] Trial 12 finished with value: 0.8581628344208398 and parameters: {'n_estimators': 519, 'max_depth': 10, 'learning_rate': 0.005760142101585202, 'subsample': 0.5491528432184791, 'colsample_bytree': 0.6617551394252136, 'gamma': 4.95334370840242}. Best is trial 12 with value: 0.8581628344208398.
# [I 2026-03-12 23:23:30,430] Trial 13 finished with value: 0.8588951000204432 and parameters: {'n_estimators': 586, 'max_depth': 10, 'learning_rate': 0.0050242268551656186, 'subsample': 0.5190265103260713, 'colsample_bytree': 0.6804347678794443, 'gamma': 4.988088079133967}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:23:42,401] Trial 14 finished with value: 0.8528546628729611 and parameters: {'n_estimators': 583, 'max_depth': 10, 'learning_rate': 0.015315700021647081, 'subsample': 0.6411489420847829, 'colsample_bytree': 0.6978462138513994, 'gamma': 4.8644561697217155}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:23:59,586] Trial 15 finished with value: 0.8530391535881015 and parameters: {'n_estimators': 1214, 'max_depth': 10, 'learning_rate': 0.008228359947816904, 'subsample': 0.50458280497156, 'colsample_bytree': 0.6981097329527572, 'gamma': 4.876299900583441}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:24:05,727] Trial 16 finished with value: 0.846449936157164 and parameters: {'n_estimators': 569, 'max_depth': 6, 'learning_rate': 0.026346753638436627, 'subsample': 0.6579730272121678, 'colsample_bytree': 0.6652056482151085, 'gamma': 3.2166848067393743}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:24:18,945] Trial 17 finished with value: 0.852490373304646 and parameters: {'n_estimators': 808, 'max_depth': 9, 'learning_rate': 0.00529247242322746, 'subsample': 0.5035084141516085, 'colsample_bytree': 0.5706957898143338, 'gamma': 3.1042229305871496}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:24:30,938] Trial 18 finished with value: 0.8488292128731286 and parameters: {'n_estimators': 1149, 'max_depth': 11, 'learning_rate': 0.015295205591870878, 'subsample': 0.6272822530613817, 'colsample_bytree': 0.840977847117867, 'gamma': 4.476959627777887}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:24:50,311] Trial 19 finished with value: 0.8526726856553022 and parameters: {'n_estimators': 1474, 'max_depth': 9, 'learning_rate': 0.007060543238271125, 'subsample': 0.5747286207339585, 'colsample_bytree': 0.700748294584125, 'gamma': 4.567710067273072}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:24:53,880] Trial 20 finished with value: 0.8534037782894142 and parameters: {'n_estimators': 201, 'max_depth': 7, 'learning_rate': 0.011050606303737944, 'subsample': 0.7947329076060653, 'colsample_bytree': 0.608995825578837, 'gamma': 3.123135818153049}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:25:17,648] Trial 21 finished with value: 0.8585284645211452 and parameters: {'n_estimators': 535, 'max_depth': 10, 'learning_rate': 0.005006360542824471, 'subsample': 0.575308330544515, 'colsample_bytree': 0.6418506733021856, 'gamma': 4.983518817599688}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:25:21,524] Trial 22 finished with value: 0.8559663727550278 and parameters: {'n_estimators': 667, 'max_depth': 11, 'learning_rate': 0.006915683411960091, 'subsample': 0.6858915865118943, 'colsample_bytree': 0.5059269045139003, 'gamma': 4.987775637955535}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:25:26,512] Trial 23 finished with value: 0.8556010777877201 and parameters: {'n_estimators': 549, 'max_depth': 11, 'learning_rate': 0.0051087988265366095, 'subsample': 0.5519404866324243, 'colsample_bytree': 0.7128970214054282, 'gamma': 4.337613399539495}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:25:30,586] Trial 24 finished with value: 0.8524893679056532 and parameters: {'n_estimators': 372, 'max_depth': 10, 'learning_rate': 0.00839033305830685, 'subsample': 0.595386825109836, 'colsample_bytree': 0.6148975177723147, 'gamma': 3.4898729877752346}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:25:34,758] Trial 25 finished with value: 0.8559665403215264 and parameters: {'n_estimators': 528, 'max_depth': 9, 'learning_rate': 0.00671032109123269, 'subsample': 0.5303583193803557, 'colsample_bytree': 0.739279695948865, 'gamma': 4.488092730845154}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:25:40,173] Trial 26 finished with value: 0.856149522938178 and parameters: {'n_estimators': 739, 'max_depth': 8, 'learning_rate': 0.005035169779832421, 'subsample': 0.6100747507442731, 'colsample_bytree': 0.6678074255509279, 'gamma': 4.998973365704641}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:25:49,519] Trial 27 finished with value: 0.8493786634225794 and parameters: {'n_estimators': 636, 'max_depth': 11, 'learning_rate': 0.008900645343225752, 'subsample': 0.6808966453919798, 'colsample_bytree': 0.6066876889780437, 'gamma': 2.7088870990642504}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:25:52,444] Trial 28 finished with value: 0.85706376575544 and parameters: {'n_estimators': 484, 'max_depth': 3, 'learning_rate': 0.013997813288219009, 'subsample': 0.5328108906063772, 'colsample_bytree': 0.5471864574236337, 'gamma': 4.18092619488087}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:25:57,895] Trial 29 finished with value: 0.8526726856553022 and parameters: {'n_estimators': 320, 'max_depth': 8, 'learning_rate': 0.019260754892355174, 'subsample': 0.6006484333971879, 'colsample_bytree': 0.8516377924860581, 'gamma': 4.644326091222494}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:26:02,374] Trial 30 finished with value: 0.8535867609060656 and parameters: {'n_estimators': 386, 'max_depth': 10, 'learning_rate': 0.006192588222515975, 'subsample': 0.7004110127568626, 'colsample_bytree': 0.6519039248402652, 'gamma': 3.7514088458848986}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:26:05,527] Trial 31 finished with value: 0.8545028469548139 and parameters: {'n_estimators': 489, 'max_depth': 6, 'learning_rate': 0.01251515316550284, 'subsample': 0.533553282798195, 'colsample_bytree': 0.5464403711543975, 'gamma': 4.2012386609536225}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:26:08,356] Trial 32 finished with value: 0.8495609757732356 and parameters: {'n_estimators': 890, 'max_depth': 3, 'learning_rate': 0.03781628351906212, 'subsample': 0.5223272595783989, 'colsample_bytree': 0.5370101792358586, 'gamma': 4.558109732213294}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:26:09,126] Trial 33 finished with value: 0.8499271085730371 and parameters: {'n_estimators': 220, 'max_depth': 3, 'learning_rate': 0.06407465767098619, 'subsample': 0.5649404964268623, 'colsample_bytree': 0.5964683717038483, 'gamma': 4.177335568107074}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:26:13,314] Trial 34 finished with value: 0.8585289672206414 and parameters: {'n_estimators': 620, 'max_depth': 9, 'learning_rate': 0.005975219422320066, 'subsample': 0.5021336375579917, 'colsample_bytree': 0.5360468784970247, 'gamma': 4.738743485612297}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:26:18,173] Trial 35 finished with value: 0.8552341071554246 and parameters: {'n_estimators': 748, 'max_depth': 9, 'learning_rate': 0.005923551974692993, 'subsample': 0.5057339988371098, 'colsample_bytree': 0.7438227408209498, 'gamma': 4.708132774807427}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:26:24,302] Trial 36 finished with value: 0.8486465653894749 and parameters: {'n_estimators': 608, 'max_depth': 8, 'learning_rate': 0.007694972381478492, 'subsample': 0.5916833825080112, 'colsample_bytree': 0.6310947703274983, 'gamma': 2.3377423136725763}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:26:27,779] Trial 37 finished with value: 0.8543190265056687 and parameters: {'n_estimators': 896, 'max_depth': 11, 'learning_rate': 0.00977572702789493, 'subsample': 0.623718368068368, 'colsample_bytree': 0.5781987767636959, 'gamma': 4.784355775969191}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:26:28,867] Trial 38 finished with value: 0.8471816990572709 and parameters: {'n_estimators': 290, 'max_depth': 10, 'learning_rate': 0.04900998891361014, 'subsample': 0.658651840947424, 'colsample_bytree': 0.6731615831757772, 'gamma': 3.411712681258959}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:26:38,357] Trial 39 finished with value: 0.8484637503393222 and parameters: {'n_estimators': 727, 'max_depth': 12, 'learning_rate': 0.006005483861520832, 'subsample': 0.5466723125935469, 'colsample_bytree': 0.7798793209724072, 'gamma': 1.7890115201197099}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:26:42,129] Trial 40 finished with value: 0.8534051188214044 and parameters: {'n_estimators': 630, 'max_depth': 9, 'learning_rate': 0.007855751575706537, 'subsample': 0.581084026535138, 'colsample_bytree': 0.5275727519588567, 'gamma': 2.741936338498626}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:26:45,196] Trial 41 finished with value: 0.8568814534047837 and parameters: {'n_estimators': 502, 'max_depth': 8, 'learning_rate': 0.006048272774391679, 'subsample': 0.5336451067693794, 'colsample_bytree': 0.5649442533590714, 'gamma': 4.3196446195439115}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:26:47,003] Trial 42 finished with value: 0.8499266058735409 and parameters: {'n_estimators': 427, 'max_depth': 5, 'learning_rate': 0.025019892019929192, 'subsample': 0.528303752591813, 'colsample_bytree': 0.5452754754855906, 'gamma': 4.055340739209961}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:26:49,894] Trial 43 finished with value: 0.8545025118218165 and parameters: {'n_estimators': 508, 'max_depth': 7, 'learning_rate': 0.011777925608798142, 'subsample': 0.5561484224587914, 'colsample_bytree': 0.6272042703276038, 'gamma': 4.726714104806063}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:26:52,268] Trial 44 finished with value: 0.8566986383546309 and parameters: {'n_estimators': 367, 'max_depth': 10, 'learning_rate': 0.00969805152463881, 'subsample': 0.5031890000546118, 'colsample_bytree': 0.5212889984868362, 'gamma': 4.448254090182202}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:26:55,241] Trial 45 finished with value: 0.8513916397722436 and parameters: {'n_estimators': 1060, 'max_depth': 9, 'learning_rate': 0.014239572914067314, 'subsample': 0.753290145561415, 'colsample_bytree': 0.5009840396428654, 'gamma': 3.9230482811761718}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:27:04,459] Trial 46 finished with value: 0.8431567517569347 and parameters: {'n_estimators': 786, 'max_depth': 11, 'learning_rate': 0.018678780842392797, 'subsample': 0.5763733211578209, 'colsample_bytree': 0.7196473849944376, 'gamma': 0.577474219123113}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:27:05,782] Trial 47 finished with value: 0.851756432040055 and parameters: {'n_estimators': 588, 'max_depth': 10, 'learning_rate': 0.09903032364847607, 'subsample': 0.9999034674096471, 'colsample_bytree': 0.588150568908814, 'gamma': 4.94848543679685}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:27:09,548] Trial 48 finished with value: 0.8583458170374912 and parameters: {'n_estimators': 459, 'max_depth': 9, 'learning_rate': 0.005478271676683528, 'subsample': 0.520208842814105, 'colsample_bytree': 0.6772235804724638, 'gamma': 4.715588461323991}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:27:14,016] Trial 49 finished with value: 0.8568819561042801 and parameters: {'n_estimators': 683, 'max_depth': 9, 'learning_rate': 0.0055580608988377665, 'subsample': 0.5537392031646681, 'colsample_bytree': 0.6847667100792212, 'gamma': 4.702812828935167}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:27:20,388] Trial 50 finished with value: 0.8501107614556837 and parameters: {'n_estimators': 434, 'max_depth': 10, 'learning_rate': 0.006653640740752446, 'subsample': 0.5005504203967442, 'colsample_bytree': 0.7671960474512184, 'gamma': 1.6227105653457043}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:27:22,268] Trial 51 finished with value: 0.8581624992878425 and parameters: {'n_estimators': 345, 'max_depth': 7, 'learning_rate': 0.005525412112888738, 'subsample': 0.5227340016782939, 'colsample_bytree': 0.6510642487786313, 'gamma': 4.295043662687052}. Best is trial 13 with value: 0.8588951000204432.
# [I 2026-03-12 23:27:24,924] Trial 52 finished with value: 0.8603589609536545 and parameters: {'n_estimators': 313, 'max_depth': 6, 'learning_rate': 0.007452286407252364, 'subsample': 0.5258045801594521, 'colsample_bytree': 0.6529771175522238, 'gamma': 4.784111727704463}. Best is trial 52 with value: 0.8603589609536545.
# [I 2026-03-12 23:27:27,218] Trial 53 finished with value: 0.8577956962220457 and parameters: {'n_estimators': 266, 'max_depth': 6, 'learning_rate': 0.007052658941345504, 'subsample': 0.8593064141097986, 'colsample_bytree': 0.6833943927080768, 'gamma': 4.830169209781186}. Best is trial 52 with value: 0.8603589609536545.
# [I 2026-03-12 23:27:31,054] Trial 54 finished with value: 0.856699308620626 and parameters: {'n_estimators': 442, 'max_depth': 5, 'learning_rate': 0.007569424539195656, 'subsample': 0.5466410027222838, 'colsample_bytree': 0.7257985258471068, 'gamma': 4.9863280274833475}. Best is trial 52 with value: 0.8603589609536545.
# [I 2026-03-12 23:27:36,249] Trial 55 finished with value: 0.8539532288388646 and parameters: {'n_estimators': 557, 'max_depth': 9, 'learning_rate': 0.006485574679074067, 'subsample': 0.6155458887391909, 'colsample_bytree': 0.8028805630628294, 'gamma': 4.463960562881331}. Best is trial 52 with value: 0.8603589609536545.
# [I 2026-03-12 23:27:45,287] Trial 56 finished with value: 0.8528558358384524 and parameters: {'n_estimators': 673, 'max_depth': 10, 'learning_rate': 0.005107386582136742, 'subsample': 0.5134708816902113, 'colsample_bytree': 0.6588166057550517, 'gamma': 3.7659116012105165}. Best is trial 52 with value: 0.8603589609536545.
# [I 2026-03-12 23:27:48,534] Trial 57 finished with value: 0.8543198643381625 and parameters: {'n_estimators': 407, 'max_depth': 11, 'learning_rate': 0.008895015834255466, 'subsample': 0.5669128156743858, 'colsample_bytree': 0.6218393329075105, 'gamma': 4.621689491493441}. Best is trial 52 with value: 0.8603589609536545.
# [I 2026-03-12 23:27:52,763] Trial 58 finished with value: 0.8572474186380864 and parameters: {'n_estimators': 554, 'max_depth': 8, 'learning_rate': 0.005484700554955135, 'subsample': 0.6426245657160624, 'colsample_bytree': 0.6933638319099223, 'gamma': 4.745346293422921}. Best is trial 52 with value: 0.8603589609536545.
# [I 2026-03-12 23:27:55,133] Trial 59 finished with value: 0.8579796842376897 and parameters: {'n_estimators': 338, 'max_depth': 8, 'learning_rate': 0.005016129520789378, 'subsample': 0.5906039797447276, 'colsample_bytree': 0.7058900481395708, 'gamma': 4.428247299285352}. Best is trial 52 with value: 0.8603589609536545.
# [I 2026-03-12 23:27:58,409] Trial 60 finished with value: 0.8559670430210229 and parameters: {'n_estimators': 463, 'max_depth': 9, 'learning_rate': 0.006335156559914632, 'subsample': 0.5526987633700385, 'colsample_bytree': 0.6391064621786985, 'gamma': 3.983133137089318}. Best is trial 52 with value: 0.8603589609536545.
# [I 2026-03-12 23:28:00,413] Trial 61 finished with value: 0.8587114471377966 and parameters: {'n_estimators': 244, 'max_depth': 7, 'learning_rate': 0.005750680984180343, 'subsample': 0.5160193810279126, 'colsample_bytree': 0.6515561733418038, 'gamma': 4.334679777482762}. Best is trial 52 with value: 0.8603589609536545.
# [I 2026-03-12 23:28:02,254] Trial 62 finished with value: 0.8592600598547533 and parameters: {'n_estimators': 230, 'max_depth': 6, 'learning_rate': 0.005579651740872828, 'subsample': 0.5154348517673182, 'colsample_bytree': 0.6729837652389381, 'gamma': 4.8824987715071995}. Best is trial 52 with value: 0.8603589609536545.
# [I 2026-03-12 23:28:04,108] Trial 63 finished with value: 0.8592605625542497 and parameters: {'n_estimators': 227, 'max_depth': 6, 'learning_rate': 0.007455326983180998, 'subsample': 0.5158364895907114, 'colsample_bytree': 0.6786098358309176, 'gamma': 4.8287829407843414}. Best is trial 52 with value: 0.8603589609536545.
# [I 2026-03-12 23:28:10,379] Trial 64 finished with value: 0.856148852672183 and parameters: {'n_estimators': 250, 'max_depth': 6, 'learning_rate': 0.008373714441043466, 'subsample': 0.5401644616671806, 'colsample_bytree': 0.9943623126296725, 'gamma': 4.869103183381355}. Best is trial 52 with value: 0.8603589609536545.
# [I 2026-03-12 23:28:11,770] Trial 65 finished with value: 0.8598091752712064 and parameters: {'n_estimators': 239, 'max_depth': 6, 'learning_rate': 0.007069171924988123, 'subsample': 0.5150385325939674, 'colsample_bytree': 0.6405131105123097, 'gamma': 4.556403704993995}. Best is trial 52 with value: 0.8603589609536545.
# [I 2026-03-12 23:28:14,642] Trial 66 finished with value: 0.8609075736706113 and parameters: {'n_estimators': 200, 'max_depth': 6, 'learning_rate': 0.007162880074553063, 'subsample': 0.5132987853646052, 'colsample_bytree': 0.6072675295401244, 'gamma': 4.276217941653796}. Best is trial 66 with value: 0.8609075736706113.
# [I 2026-03-12 23:28:16,909] Trial 67 finished with value: 0.8570639333219388 and parameters: {'n_estimators': 228, 'max_depth': 6, 'learning_rate': 0.007346304469145632, 'subsample': 0.9377770969806047, 'colsample_bytree': 0.6530557869555584, 'gamma': 4.25979363151448}. Best is trial 66 with value: 0.8609075736706113.
# [I 2026-03-12 23:28:19,329] Trial 68 finished with value: 0.8587122849702904 and parameters: {'n_estimators': 297, 'max_depth': 7, 'learning_rate': 0.01038896567232553, 'subsample': 0.5196198318319154, 'colsample_bytree': 0.6044361230025843, 'gamma': 4.559217213990486}. Best is trial 66 with value: 0.8609075736706113.
# [I 2026-03-12 23:28:20,972] Trial 69 finished with value: 0.8594430424714048 and parameters: {'n_estimators': 290, 'max_depth': 5, 'learning_rate': 0.00850616765935227, 'subsample': 0.565299362041757, 'colsample_bytree': 0.6000185723356326, 'gamma': 4.564458698828622}. Best is trial 66 with value: 0.8609075736706113.
# [I 2026-03-12 23:28:22,497] Trial 70 finished with value: 0.8588935919219542 and parameters: {'n_estimators': 204, 'max_depth': 5, 'learning_rate': 0.00894910886550875, 'subsample': 0.5640907029269765, 'colsample_bytree': 0.953100540789048, 'gamma': 4.08854067007741}. Best is trial 66 with value: 0.8609075736706113.
# [I 2026-03-12 23:28:23,805] Trial 71 finished with value: 0.8605414408708094 and parameters: {'n_estimators': 282, 'max_depth': 4, 'learning_rate': 0.008871639613889658, 'subsample': 0.5652485213337203, 'colsample_bytree': 0.621247926140285, 'gamma': 4.084219650432858}. Best is trial 66 with value: 0.8609075736706113.
# [I 2026-03-12 23:28:24,946] Trial 72 finished with value: 0.8609074061041124 and parameters: {'n_estimators': 287, 'max_depth': 4, 'learning_rate': 0.008168727907387577, 'subsample': 0.5395978021962675, 'colsample_bytree': 0.5871616378458879, 'gamma': 4.595684245052914}. Best is trial 66 with value: 0.8609075736706113.
# [I 2026-03-12 23:28:26,385] Trial 73 finished with value: 0.8605409381713132 and parameters: {'n_estimators': 287, 'max_depth': 4, 'learning_rate': 0.00815584379802312, 'subsample': 0.5388402888250656, 'colsample_bytree': 0.5624357963528579, 'gamma': 4.558993685620507}. Best is trial 66 with value: 0.8609075736706113.
# [I 2026-03-12 23:28:27,639] Trial 74 finished with value: 0.8588940946214505 and parameters: {'n_estimators': 313, 'max_depth': 4, 'learning_rate': 0.01057693987387913, 'subsample': 0.541067998679174, 'colsample_bytree': 0.5668032808736504, 'gamma': 3.78211600772765}. Best is trial 66 with value: 0.8609075736706113.
# [I 2026-03-12 23:28:28,841] Trial 75 finished with value: 0.8607235856549671 and parameters: {'n_estimators': 281, 'max_depth': 4, 'learning_rate': 0.008137613281432475, 'subsample': 0.6011230857625417, 'colsample_bytree': 0.587796611455431, 'gamma': 4.395813495157912}. Best is trial 66 with value: 0.8609075736706113.
# [I 2026-03-12 23:28:30,163] Trial 76 finished with value: 0.8577963664880407 and parameters: {'n_estimators': 273, 'max_depth': 4, 'learning_rate': 0.011546300765993911, 'subsample': 0.5779196821486964, 'colsample_bytree': 0.5926126809447102, 'gamma': 3.506566052842994}. Best is trial 66 with value: 0.8609075736706113.
# [I 2026-03-12 23:28:31,555] Trial 77 finished with value: 0.8594430424714048 and parameters: {'n_estimators': 351, 'max_depth': 4, 'learning_rate': 0.008377207927401018, 'subsample': 0.6138477550984932, 'colsample_bytree': 0.5569148540098942, 'gamma': 4.094124432469252}. Best is trial 66 with value: 0.8609075736706113.
# [I 2026-03-12 23:28:32,862] Trial 78 finished with value: 0.8561491878051803 and parameters: {'n_estimators': 300, 'max_depth': 5, 'learning_rate': 0.009682865700158643, 'subsample': 0.6028094923203059, 'colsample_bytree': 0.6049724655127068, 'gamma': 4.405301014055014}. Best is trial 66 with value: 0.8609075736706113.
# [I 2026-03-12 23:28:34,571] Trial 79 finished with value: 0.8568817885377811 and parameters: {'n_estimators': 392, 'max_depth': 4, 'learning_rate': 0.012803152988509028, 'subsample': 0.566155289428898, 'colsample_bytree': 0.579365271870081, 'gamma': 4.557361332060965}. Best is trial 66 with value: 0.8609075736706113.
# [I 2026-03-12 23:28:35,363] Trial 80 finished with value: 0.8610893833217712 and parameters: {'n_estimators': 271, 'max_depth': 3, 'learning_rate': 0.007943185779356881, 'subsample': 0.5843727523942688, 'colsample_bytree': 0.6190998904493074, 'gamma': 4.193249784897266}. Best is trial 80 with value: 0.8610893833217712.
# [I 2026-03-12 23:28:36,139] Trial 81 finished with value: 0.8610895508882701 and parameters: {'n_estimators': 276, 'max_depth': 3, 'learning_rate': 0.007947624998499514, 'subsample': 0.5848959373654464, 'colsample_bytree': 0.6251963770744631, 'gamma': 3.9078722105790065}. Best is trial 81 with value: 0.8610895508882701.
# [I 2026-03-12 23:28:36,912] Trial 82 finished with value: 0.8607234180884683 and parameters: {'n_estimators': 263, 'max_depth': 3, 'learning_rate': 0.007815773401290409, 'subsample': 0.5827069180104252, 'colsample_bytree': 0.6251831046329483, 'gamma': 3.6719122075615913}. Best is trial 81 with value: 0.8610895508882701.
# [I 2026-03-12 23:28:37,998] Trial 83 finished with value: 0.8623710994708249 and parameters: {'n_estimators': 265, 'max_depth': 3, 'learning_rate': 0.009069524365169635, 'subsample': 0.6378675456114039, 'colsample_bytree': 0.6232697236869671, 'gamma': 3.68162227828152}. Best is trial 83 with value: 0.8623710994708249.
# [I 2026-03-12 23:28:38,738] Trial 84 finished with value: 0.8618214813548757 and parameters: {'n_estimators': 260, 'max_depth': 3, 'learning_rate': 0.009292512998890544, 'subsample': 0.639069911154504, 'colsample_bytree': 0.6186544168277202, 'gamma': 3.622205580919868}. Best is trial 83 with value: 0.8623710994708249.
# [I 2026-03-12 23:28:39,386] Trial 85 finished with value: 0.8599916551883615 and parameters: {'n_estimators': 204, 'max_depth': 3, 'learning_rate': 0.009274856193862781, 'subsample': 0.638868506487928, 'colsample_bytree': 0.6152374791635848, 'gamma': 3.3215164653623366}. Best is trial 83 with value: 0.8623710994708249.
# [I 2026-03-12 23:28:40,321] Trial 86 finished with value: 0.8620051342375221 and parameters: {'n_estimators': 342, 'max_depth': 3, 'learning_rate': 0.010304592499822168, 'subsample': 0.656277951481415, 'colsample_bytree': 0.6250987224301797, 'gamma': 3.87043779813768}. Best is trial 83 with value: 0.8623710994708249.
# [I 2026-03-12 23:28:41,333] Trial 87 finished with value: 0.861456018821069 and parameters: {'n_estimators': 356, 'max_depth': 3, 'learning_rate': 0.010189103517213806, 'subsample': 0.6669423535221247, 'colsample_bytree': 0.5804914360653967, 'gamma': 2.90953077072385}. Best is trial 83 with value: 0.8623710994708249.
# [I 2026-03-12 23:28:42,614] Trial 88 finished with value: 0.8581618290218472 and parameters: {'n_estimators': 346, 'max_depth': 3, 'learning_rate': 0.017046028044000645, 'subsample': 0.6669846468260081, 'colsample_bytree': 0.5868783007291123, 'gamma': 2.9702278446204837}. Best is trial 83 with value: 0.8623710994708249.
# [I 2026-03-12 23:28:44,083] Trial 89 finished with value: 0.8599918227548603 and parameters: {'n_estimators': 375, 'max_depth': 3, 'learning_rate': 0.01113475059874701, 'subsample': 0.7110408069172792, 'colsample_bytree': 0.5769685943929743, 'gamma': 3.6095863041112324}. Best is trial 83 with value: 0.8623710994708249.
# [I 2026-03-12 23:28:47,234] Trial 90 finished with value: 0.8508416865232968 and parameters: {'n_estimators': 1406, 'max_depth': 3, 'learning_rate': 0.010332292450850574, 'subsample': 0.6743340443041913, 'colsample_bytree': 0.6116085334971293, 'gamma': 3.938161179183873}. Best is trial 83 with value: 0.8623710994708249.
# [I 2026-03-12 23:28:47,954] Trial 91 finished with value: 0.8616388338712218 and parameters: {'n_estimators': 258, 'max_depth': 3, 'learning_rate': 0.009880792349639437, 'subsample': 0.6327913082480658, 'colsample_bytree': 0.6247849826138037, 'gamma': 3.6592726714445263}. Best is trial 83 with value: 0.8623710994708249.
# [I 2026-03-12 23:28:48,855] Trial 92 finished with value: 0.8609074061041124 and parameters: {'n_estimators': 329, 'max_depth': 3, 'learning_rate': 0.013295086694821451, 'subsample': 0.6309911716059632, 'colsample_bytree': 0.6342148897377758, 'gamma': 3.5673173680194066}. Best is trial 83 with value: 0.8623710994708249.
# [I 2026-03-12 23:28:50,718] Trial 93 finished with value: 0.8598090077047076 and parameters: {'n_estimators': 331, 'max_depth': 3, 'learning_rate': 0.01285329872281349, 'subsample': 0.6474759113343523, 'colsample_bytree': 0.6368864436722904, 'gamma': 3.2279682648971564}. Best is trial 83 with value: 0.8623710994708249.
# [I 2026-03-12 23:28:52,253] Trial 94 finished with value: 0.861638666304723 and parameters: {'n_estimators': 371, 'max_depth': 3, 'learning_rate': 0.009977796374441157, 'subsample': 0.6292065863756756, 'colsample_bytree': 0.6310431630621985, 'gamma': 3.586863031839333}. Best is trial 83 with value: 0.8623710994708249.
# [I 2026-03-12 23:28:54,442] Trial 95 finished with value: 0.8599921578878578 and parameters: {'n_estimators': 415, 'max_depth': 3, 'learning_rate': 0.011633682800736693, 'subsample': 0.6977823757992263, 'colsample_bytree': 0.5962094355751545, 'gamma': 2.9157464917929232}. Best is trial 83 with value: 0.8623710994708249.
# [I 2026-03-12 23:28:55,844] Trial 96 finished with value: 0.8618218164878731 and parameters: {'n_estimators': 367, 'max_depth': 3, 'learning_rate': 0.010271802452257232, 'subsample': 0.6528388180164989, 'colsample_bytree': 0.6170409518344636, 'gamma': 3.858052288007745}. Best is trial 83 with value: 0.8623710994708249.
# [I 2026-03-12 23:28:57,973] Trial 97 finished with value: 0.860723753221466 and parameters: {'n_estimators': 398, 'max_depth': 3, 'learning_rate': 0.010026701698137106, 'subsample': 0.6541315747784399, 'colsample_bytree': 0.611195411441805, 'gamma': 3.3448983465733533}. Best is trial 83 with value: 0.8623710994708249.
# [I 2026-03-12 23:28:59,345] Trial 98 finished with value: 0.8621879492876747 and parameters: {'n_estimators': 361, 'max_depth': 3, 'learning_rate': 0.010905376430053947, 'subsample': 0.6282120299871055, 'colsample_bytree': 0.6223058836671121, 'gamma': 3.8583397565129665}. Best is trial 83 with value: 0.8623710994708249.
# [I 2026-03-12 23:29:00,967] Trial 99 finished with value: 0.8618219840543719 and parameters: {'n_estimators': 367, 'max_depth': 3, 'learning_rate': 0.011127371340498583, 'subsample': 0.6266306294631364, 'colsample_bytree': 0.6275359591195242, 'gamma': 3.8393417428330734}. Best is trial 83 with value: 0.8623710994708249.
# [I 2026-03-12 23:29:00,969] A new study created in memory with name: no-name-87bd6efd-3e65-4839-a613-79334b11d355
# ✅ Best XGBoost Params: {'n_estimators': 265, 'max_depth': 3, 'learning_rate': 0.009069524365169635, 'subsample': 0.6378675456114039, 'colsample_bytree': 0.6232697236869671, 'gamma': 3.68162227828152}
#
# 🚀 Starting Optuna Tuning for LightGBM...
# [I 2026-03-12 23:29:11,934] Trial 0 finished with value: 0.837114638944465 and parameters: {'n_estimators': 1128, 'max_depth': 8, 'learning_rate': 0.05599152693395187, 'subsample': 0.9590834715633707, 'colsample_bytree': 0.5800906154086072, 'num_leaves': 113}. Best is trial 0 with value: 0.837114638944465.
# [I 2026-03-12 23:29:22,833] Trial 1 finished with value: 0.8394942507934273 and parameters: {'n_estimators': 766, 'max_depth': 9, 'learning_rate': 0.027882974766324554, 'subsample': 0.7880452898199759, 'colsample_bytree': 0.6696551849394585, 'num_leaves': 150}. Best is trial 1 with value: 0.8394942507934273.
# [I 2026-03-12 23:29:29,418] Trial 2 finished with value: 0.8362002285607042 and parameters: {'n_estimators': 482, 'max_depth': 9, 'learning_rate': 0.09526883496353544, 'subsample': 0.5418565349724128, 'colsample_bytree': 0.883148995365387, 'num_leaves': 133}. Best is trial 1 with value: 0.8394942507934273.
# [I 2026-03-12 23:29:31,533] Trial 3 finished with value: 0.8585274591221526 and parameters: {'n_estimators': 816, 'max_depth': 3, 'learning_rate': 0.005406518941776092, 'subsample': 0.5273422925361564, 'colsample_bytree': 0.6217990940125746, 'num_leaves': 39}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:29:38,491] Trial 4 finished with value: 0.8369338346922977 and parameters: {'n_estimators': 479, 'max_depth': 10, 'learning_rate': 0.08517038338854227, 'subsample': 0.9339306830634633, 'colsample_bytree': 0.7129975901183648, 'num_leaves': 123}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:29:54,350] Trial 5 finished with value: 0.841140591643794 and parameters: {'n_estimators': 1232, 'max_depth': 8, 'learning_rate': 0.006833846869062122, 'subsample': 0.6946648442653692, 'colsample_bytree': 0.6541809838669204, 'num_leaves': 138}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:29:59,309] Trial 6 finished with value: 0.8362010663931981 and parameters: {'n_estimators': 715, 'max_depth': 6, 'learning_rate': 0.08200849336515766, 'subsample': 0.5067302524268311, 'colsample_bytree': 0.7662841370750432, 'num_leaves': 100}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:30:16,658] Trial 7 finished with value: 0.8369301482293248 and parameters: {'n_estimators': 1152, 'max_depth': 10, 'learning_rate': 0.009629980214645336, 'subsample': 0.6492202605005746, 'colsample_bytree': 0.9874817455177938, 'num_leaves': 82}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:30:21,126] Trial 8 finished with value: 0.8340002479984182 and parameters: {'n_estimators': 1474, 'max_depth': 4, 'learning_rate': 0.016120221700052357, 'subsample': 0.7013041640644495, 'colsample_bytree': 0.6269239133303084, 'num_leaves': 124}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:30:23,547] Trial 9 finished with value: 0.8270462382996693 and parameters: {'n_estimators': 995, 'max_depth': 3, 'learning_rate': 0.0960088391651664, 'subsample': 0.9708280481522416, 'colsample_bytree': 0.8864273544021282, 'num_leaves': 63}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:30:24,764] Trial 10 finished with value: 0.8550506218392769 and parameters: {'n_estimators': 247, 'max_depth': 5, 'learning_rate': 0.005243637208357357, 'subsample': 0.6105620625576996, 'colsample_bytree': 0.5015638387842116, 'num_leaves': 20}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:30:26,240] Trial 11 finished with value: 0.8528551655724573 and parameters: {'n_estimators': 205, 'max_depth': 5, 'learning_rate': 0.005204929061032242, 'subsample': 0.5984158086045088, 'colsample_bytree': 0.5231470296671995, 'num_leaves': 20}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:30:27,340] Trial 12 finished with value: 0.853587096039063 and parameters: {'n_estimators': 217, 'max_depth': 6, 'learning_rate': 0.010383391457168297, 'subsample': 0.5797264109287081, 'colsample_bytree': 0.50234652649812, 'num_leaves': 23}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:30:32,429] Trial 13 finished with value: 0.8488292128731286 and parameters: {'n_estimators': 504, 'max_depth': 12, 'learning_rate': 0.005618105220039656, 'subsample': 0.7890652245257329, 'colsample_bytree': 0.5848105658379062, 'num_leaves': 49}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:30:34,058] Trial 14 finished with value: 0.8446152505621856 and parameters: {'n_estimators': 632, 'max_depth': 3, 'learning_rate': 0.022459553423819476, 'subsample': 0.6285502080533538, 'colsample_bytree': 0.5635956282634151, 'num_leaves': 44}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:30:38,353] Trial 15 finished with value: 0.8411384132793099 and parameters: {'n_estimators': 936, 'max_depth': 5, 'learning_rate': 0.009029277080144034, 'subsample': 0.5055466829536901, 'colsample_bytree': 0.7728873753135309, 'num_leaves': 41}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:30:39,631] Trial 16 finished with value: 0.851573114290406 and parameters: {'n_estimators': 370, 'max_depth': 4, 'learning_rate': 0.014613017025116345, 'subsample': 0.5770290747151487, 'colsample_bytree': 0.5024030625234388, 'num_leaves': 68}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:30:47,528] Trial 17 finished with value: 0.8365655235280121 and parameters: {'n_estimators': 1368, 'max_depth': 6, 'learning_rate': 0.0330272188797605, 'subsample': 0.8808252344640681, 'colsample_bytree': 0.6065467252956228, 'num_leaves': 33}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:30:50,891] Trial 18 finished with value: 0.847727965843245 and parameters: {'n_estimators': 841, 'max_depth': 4, 'learning_rate': 0.00742991703682311, 'subsample': 0.6801623093426311, 'colsample_bytree': 0.7148569208686556, 'num_leaves': 59}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:30:52,295] Trial 19 finished with value: 0.8479097754944049 and parameters: {'n_estimators': 627, 'max_depth': 3, 'learning_rate': 0.013192849175970175, 'subsample': 0.7606711697929747, 'colsample_bytree': 0.562170975374917, 'num_leaves': 76}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:30:55,525] Trial 20 finished with value: 0.835466622429111 and parameters: {'n_estimators': 349, 'max_depth': 7, 'learning_rate': 0.03988776877211581, 'subsample': 0.5499383130947012, 'colsample_bytree': 0.8236327064712293, 'num_leaves': 97}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:30:56,775] Trial 21 finished with value: 0.851573114290406 and parameters: {'n_estimators': 254, 'max_depth': 6, 'learning_rate': 0.010544169006126538, 'subsample': 0.6095168016083478, 'colsample_bytree': 0.5046728235386223, 'num_leaves': 20}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:30:58,707] Trial 22 finished with value: 0.8550504542727781 and parameters: {'n_estimators': 300, 'max_depth': 5, 'learning_rate': 0.005016699827302188, 'subsample': 0.5702615415080878, 'colsample_bytree': 0.5429926937179805, 'num_leaves': 30}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:31:00,469] Trial 23 finished with value: 0.8541353736230223 and parameters: {'n_estimators': 324, 'max_depth': 5, 'learning_rate': 0.005008058966476478, 'subsample': 0.5414030232838076, 'colsample_bytree': 0.5416457918641394, 'num_leaves': 33}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:31:02,479] Trial 24 finished with value: 0.854867974355623 and parameters: {'n_estimators': 558, 'max_depth': 4, 'learning_rate': 0.006761908489952815, 'subsample': 0.6525411432005918, 'colsample_bytree': 0.6326706751819798, 'num_leaves': 53}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:31:04,641] Trial 25 finished with value: 0.8526716802563097 and parameters: {'n_estimators': 378, 'max_depth': 5, 'learning_rate': 0.007359378260602609, 'subsample': 0.7246679512531005, 'colsample_bytree': 0.6837712699379508, 'num_leaves': 32}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:31:07,995] Trial 26 finished with value: 0.8493779931565841 and parameters: {'n_estimators': 410, 'max_depth': 7, 'learning_rate': 0.00617629708261026, 'subsample': 0.8428973176703864, 'colsample_bytree': 0.6040489844551061, 'num_leaves': 36}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:31:10,178] Trial 27 finished with value: 0.8477269604442524 and parameters: {'n_estimators': 981, 'max_depth': 3, 'learning_rate': 0.00870276942359384, 'subsample': 0.5602313815890824, 'colsample_bytree': 0.5555112144560297, 'num_leaves': 28}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:31:11,142] Trial 28 finished with value: 0.8535859230735717 and parameters: {'n_estimators': 289, 'max_depth': 4, 'learning_rate': 0.01817037392618849, 'subsample': 0.5065974999910656, 'colsample_bytree': 0.5383537311799061, 'num_leaves': 52}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:31:15,947] Trial 29 finished with value: 0.8378443910465869 and parameters: {'n_estimators': 1118, 'max_depth': 5, 'learning_rate': 0.012226946817370774, 'subsample': 0.628208659152264, 'colsample_bytree': 0.5958722990070974, 'num_leaves': 41}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:31:21,308] Trial 30 finished with value: 0.83967706584358 and parameters: {'n_estimators': 674, 'max_depth': 7, 'learning_rate': 0.0567687535864241, 'subsample': 0.654718286922254, 'colsample_bytree': 0.6364462072416901, 'num_leaves': 98}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:31:23,491] Trial 31 finished with value: 0.8545016739893226 and parameters: {'n_estimators': 554, 'max_depth': 4, 'learning_rate': 0.006272090388541395, 'subsample': 0.6579019177155916, 'colsample_bytree': 0.6274986084235741, 'num_leaves': 54}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:31:25,105] Trial 32 finished with value: 0.8523030339590265 and parameters: {'n_estimators': 788, 'max_depth': 3, 'learning_rate': 0.007776080612481662, 'subsample': 0.603258464012369, 'colsample_bytree': 0.6882042559606844, 'num_leaves': 70}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:31:27,524] Trial 33 finished with value: 0.8574292282892465 and parameters: {'n_estimators': 564, 'max_depth': 4, 'learning_rate': 0.005058718779668344, 'subsample': 0.5364892978543823, 'colsample_bytree': 0.5793194149117028, 'num_leaves': 47}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:31:29,635] Trial 34 finished with value: 0.8535869284725643 and parameters: {'n_estimators': 433, 'max_depth': 5, 'learning_rate': 0.005183432753010293, 'subsample': 0.5438113820881061, 'colsample_bytree': 0.5787848543769759, 'num_leaves': 27}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:31:34,515] Trial 35 finished with value: 0.8466334214733117 and parameters: {'n_estimators': 537, 'max_depth': 8, 'learning_rate': 0.005834716340817745, 'subsample': 0.5275074318062191, 'colsample_bytree': 0.5289744017535072, 'num_leaves': 43}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:31:37,174] Trial 36 finished with value: 0.8444336084775242 and parameters: {'n_estimators': 897, 'max_depth': 4, 'learning_rate': 0.008679578419742756, 'subsample': 0.5753706912555446, 'colsample_bytree': 0.573943898813565, 'num_leaves': 38}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:31:38,961] Trial 37 finished with value: 0.8570622576569511 and parameters: {'n_estimators': 772, 'max_depth': 3, 'learning_rate': 0.006380960663663576, 'subsample': 0.5254622202563276, 'colsample_bytree': 0.6696491227793222, 'num_leaves': 29}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:31:40,857] Trial 38 finished with value: 0.8568801128727935 and parameters: {'n_estimators': 738, 'max_depth': 3, 'learning_rate': 0.006633345863049623, 'subsample': 0.5257925040323111, 'colsample_bytree': 0.7308607841285951, 'num_leaves': 90}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:31:42,563] Trial 39 finished with value: 0.8466282269118499 and parameters: {'n_estimators': 758, 'max_depth': 3, 'learning_rate': 0.011959764463547651, 'subsample': 0.5265539770528804, 'colsample_bytree': 0.7296547475024796, 'num_leaves': 90}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:31:44,813] Trial 40 finished with value: 0.8497404394934129 and parameters: {'n_estimators': 849, 'max_depth': 3, 'learning_rate': 0.00783307326158791, 'subsample': 0.5002373040710459, 'colsample_bytree': 0.7914564905268311, 'num_leaves': 107}. Best is trial 3 with value: 0.8585274591221526.
# [I 2026-03-12 23:31:46,728] Trial 41 finished with value: 0.8592592220222596 and parameters: {'n_estimators': 711, 'max_depth': 3, 'learning_rate': 0.00634401304057774, 'subsample': 0.5264759634685053, 'colsample_bytree': 0.6583671978212864, 'num_leaves': 112}. Best is trial 41 with value: 0.8592592220222596.
# [I 2026-03-12 23:31:48,439] Trial 42 finished with value: 0.8576117082064016 and parameters: {'n_estimators': 717, 'max_depth': 3, 'learning_rate': 0.00648760214233276, 'subsample': 0.5340199461390578, 'colsample_bytree': 0.6635245838951186, 'num_leaves': 118}. Best is trial 41 with value: 0.8592592220222596.
# [I 2026-03-12 23:31:50,252] Trial 43 finished with value: 0.8598083374387124 and parameters: {'n_estimators': 636, 'max_depth': 3, 'learning_rate': 0.0059755694834360724, 'subsample': 0.5310696290465292, 'colsample_bytree': 0.6637271386291359, 'num_leaves': 117}. Best is trial 43 with value: 0.8598083374387124.
# [I 2026-03-12 23:31:52,219] Trial 44 finished with value: 0.8534036107229154 and parameters: {'n_estimators': 620, 'max_depth': 4, 'learning_rate': 0.005822603654839948, 'subsample': 0.5508753199837128, 'colsample_bytree': 0.6640160851063099, 'num_leaves': 122}. Best is trial 43 with value: 0.8598083374387124.
# [I 2026-03-12 23:32:03,816] Trial 45 finished with value: 0.8429709205098043 and parameters: {'n_estimators': 683, 'max_depth': 10, 'learning_rate': 0.01018629081800301, 'subsample': 0.587573990563002, 'colsample_bytree': 0.6985072271472156, 'num_leaves': 142}. Best is trial 43 with value: 0.8598083374387124.
# [I 2026-03-12 23:32:05,257] Trial 46 finished with value: 0.8568796101732972 and parameters: {'n_estimators': 599, 'max_depth': 3, 'learning_rate': 0.008260506108464554, 'subsample': 0.5562208071252497, 'colsample_bytree': 0.6518096598532942, 'num_leaves': 117}. Best is trial 43 with value: 0.8598083374387124.
# [I 2026-03-12 23:32:07,976] Trial 47 finished with value: 0.8502915657078512 and parameters: {'n_estimators': 704, 'max_depth': 4, 'learning_rate': 0.007112844122446095, 'subsample': 0.6266986531065848, 'colsample_bytree': 0.9672580508701935, 'num_leaves': 110}. Best is trial 43 with value: 0.8598083374387124.
# [I 2026-03-12 23:32:16,503] Trial 48 finished with value: 0.840591978926837 and parameters: {'n_estimators': 450, 'max_depth': 12, 'learning_rate': 0.019190876425538184, 'subsample': 0.5248418573209797, 'colsample_bytree': 0.6480664386204911, 'num_leaves': 132}. Best is trial 43 with value: 0.8598083374387124.
# [I 2026-03-12 23:32:18,459] Trial 49 finished with value: 0.8579783437056996 and parameters: {'n_estimators': 811, 'max_depth': 3, 'learning_rate': 0.005764918088949724, 'subsample': 0.9197901670089512, 'colsample_bytree': 0.6144787752339134, 'num_leaves': 105}. Best is trial 43 with value: 0.8598083374387124.
# [I 2026-03-12 23:32:20,676] Trial 50 finished with value: 0.8528519818089808 and parameters: {'n_estimators': 1034, 'max_depth': 3, 'learning_rate': 0.005900358909356545, 'subsample': 0.9463458249066368, 'colsample_bytree': 0.7507257060598396, 'num_leaves': 104}. Best is trial 43 with value: 0.8598083374387124.
# [I 2026-03-12 23:32:23,528] Trial 51 finished with value: 0.8526711775568133 and parameters: {'n_estimators': 821, 'max_depth': 4, 'learning_rate': 0.0058184020016960455, 'subsample': 0.8697321033211282, 'colsample_bytree': 0.615482541274416, 'num_leaves': 114}. Best is trial 43 with value: 0.8598083374387124.
# [I 2026-03-12 23:32:25,532] Trial 52 finished with value: 0.8532184497417801 and parameters: {'n_estimators': 903, 'max_depth': 3, 'learning_rate': 0.00714932970622175, 'subsample': 0.9180963367657601, 'colsample_bytree': 0.5943636246051609, 'num_leaves': 129}. Best is trial 43 with value: 0.8598083374387124.
# [I 2026-03-12 23:32:35,345] Trial 53 finished with value: 0.8429707529433056 and parameters: {'n_estimators': 661, 'max_depth': 9, 'learning_rate': 0.009440657441957663, 'subsample': 0.7935430473202374, 'colsample_bytree': 0.6751655954777018, 'num_leaves': 118}. Best is trial 43 with value: 0.8598083374387124.
# [I 2026-03-12 23:32:37,026] Trial 54 finished with value: 0.8590764069721069 and parameters: {'n_estimators': 797, 'max_depth': 3, 'learning_rate': 0.005512881560506763, 'subsample': 0.8325006689897271, 'colsample_bytree': 0.7067385352885207, 'num_leaves': 126}. Best is trial 43 with value: 0.8598083374387124.
# [I 2026-03-12 23:32:39,104] Trial 55 finished with value: 0.8568794426067985 and parameters: {'n_estimators': 787, 'max_depth': 3, 'learning_rate': 0.006451826116368036, 'subsample': 0.8435942801877782, 'colsample_bytree': 0.7032669712334484, 'num_leaves': 141}. Best is trial 43 with value: 0.8598083374387124.
# [I 2026-03-12 23:32:57,056] Trial 56 finished with value: 0.8440706594411992 and parameters: {'n_estimators': 895, 'max_depth': 11, 'learning_rate': 0.005599879094724909, 'subsample': 0.9782345406893949, 'colsample_bytree': 0.654924842295338, 'num_leaves': 127}. Best is trial 43 with value: 0.8598083374387124.
# [I 2026-03-12 23:32:59,016] Trial 57 finished with value: 0.8543170157076835 and parameters: {'n_estimators': 721, 'max_depth': 3, 'learning_rate': 0.008039731108856484, 'subsample': 0.9078018075606099, 'colsample_bytree': 0.7167154251051403, 'num_leaves': 148}. Best is trial 43 with value: 0.8598083374387124.
# [I 2026-03-12 23:33:01,636] Trial 58 finished with value: 0.8314405021632835 and parameters: {'n_estimators': 954, 'max_depth': 4, 'learning_rate': 0.06908244004498369, 'subsample': 0.8167891004288366, 'colsample_bytree': 0.6130952529790965, 'num_leaves': 136}. Best is trial 43 with value: 0.8598083374387124.
# [I 2026-03-12 23:33:03,947] Trial 59 finished with value: 0.846445579428196 and parameters: {'n_estimators': 801, 'max_depth': 3, 'learning_rate': 0.011212817616795158, 'subsample': 0.7703283217991079, 'colsample_bytree': 0.7499277000532653, 'num_leaves': 103}. Best is trial 43 with value: 0.8598083374387124.
# [I 2026-03-12 23:33:06,656] Trial 60 finished with value: 0.8292426999654813 and parameters: {'n_estimators': 870, 'max_depth': 4, 'learning_rate': 0.04047824395289458, 'subsample': 0.719805171234647, 'colsample_bytree': 0.6895887629184639, 'num_leaves': 120}. Best is trial 43 with value: 0.8598083374387124.
# [I 2026-03-12 23:33:08,210] Trial 61 finished with value: 0.8598083374387124 and parameters: {'n_estimators': 722, 'max_depth': 3, 'learning_rate': 0.00547172385034037, 'subsample': 0.5880138194828248, 'colsample_bytree': 0.6382697319626431, 'num_leaves': 112}. Best is trial 43 with value: 0.8598083374387124.
# [I 2026-03-12 23:33:10,189] Trial 62 finished with value: 0.860174470238514 and parameters: {'n_estimators': 724, 'max_depth': 3, 'learning_rate': 0.00554316521017076, 'subsample': 0.5885130591003798, 'colsample_bytree': 0.6401730846002289, 'num_leaves': 112}. Best is trial 62 with value: 0.860174470238514.
# [I 2026-03-12 23:33:12,266] Trial 63 finished with value: 0.855598229157241 and parameters: {'n_estimators': 1041, 'max_depth': 3, 'learning_rate': 0.005477065506119406, 'subsample': 0.5867029186762914, 'colsample_bytree': 0.6419938386557915, 'num_leaves': 111}. Best is trial 62 with value: 0.860174470238514.
# [I 2026-03-12 23:33:15,317] Trial 64 finished with value: 0.8512064787911082 and parameters: {'n_estimators': 820, 'max_depth': 4, 'learning_rate': 0.006923656209051597, 'subsample': 0.6768102653692514, 'colsample_bytree': 0.6263226720660255, 'num_leaves': 94}. Best is trial 62 with value: 0.860174470238514.
# [I 2026-03-12 23:33:16,672] Trial 65 finished with value: 0.8601743026720154 and parameters: {'n_estimators': 595, 'max_depth': 3, 'learning_rate': 0.005333686841026551, 'subsample': 0.998166007930932, 'colsample_bytree': 0.6195405700084607, 'num_leaves': 124}. Best is trial 62 with value: 0.860174470238514.
# [I 2026-03-12 23:33:18,789] Trial 66 finished with value: 0.8587107768718015 and parameters: {'n_estimators': 482, 'max_depth': 4, 'learning_rate': 0.005419351338552621, 'subsample': 0.5691661406840655, 'colsample_bytree': 0.683256195016713, 'num_leaves': 80}. Best is trial 62 with value: 0.860174470238514.
# [I 2026-03-12 23:33:20,669] Trial 67 finished with value: 0.8367449872481896 and parameters: {'n_estimators': 591, 'max_depth': 4, 'learning_rate': 0.026958914856004337, 'subsample': 0.5703308881843295, 'colsample_bytree': 0.678686991112565, 'num_leaves': 126}. Best is trial 62 with value: 0.860174470238514.
# [I 2026-03-12 23:33:22,289] Trial 68 finished with value: 0.8609064007051197 and parameters: {'n_estimators': 500, 'max_depth': 3, 'learning_rate': 0.005349127354905027, 'subsample': 0.5992266054464054, 'colsample_bytree': 0.7037881072851143, 'num_leaves': 86}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:33:23,570] Trial 69 finished with value: 0.8596256899550585 and parameters: {'n_estimators': 515, 'max_depth': 3, 'learning_rate': 0.005048371140360728, 'subsample': 0.623313573478971, 'colsample_bytree': 0.7944288848434946, 'num_leaves': 113}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:33:24,703] Trial 70 finished with value: 0.8592602274212521 and parameters: {'n_estimators': 501, 'max_depth': 3, 'learning_rate': 0.007245847628034673, 'subsample': 0.6245036660771794, 'colsample_bytree': 0.8301180001049443, 'num_leaves': 113}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:33:26,349] Trial 71 finished with value: 0.8598088401382087 and parameters: {'n_estimators': 531, 'max_depth': 3, 'learning_rate': 0.005047169187217498, 'subsample': 0.6167019066736217, 'colsample_bytree': 0.8371673332108865, 'num_leaves': 114}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:33:27,700] Trial 72 finished with value: 0.8601746378050128 and parameters: {'n_estimators': 492, 'max_depth': 3, 'learning_rate': 0.0050278505181011995, 'subsample': 0.6183229384832125, 'colsample_bytree': 0.8374477041169185, 'num_leaves': 108}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:33:28,655] Trial 73 finished with value: 0.8590769096716031 and parameters: {'n_estimators': 414, 'max_depth': 3, 'learning_rate': 0.005005789781224477, 'subsample': 0.604721874524457, 'colsample_bytree': 0.8623020323943034, 'num_leaves': 107}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:33:31,303] Trial 74 finished with value: 0.8568816209712825 and parameters: {'n_estimators': 647, 'max_depth': 4, 'learning_rate': 0.005008013209675268, 'subsample': 0.6358639137601814, 'colsample_bytree': 0.8322177406625623, 'num_leaves': 100}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:33:32,458] Trial 75 finished with value: 0.8585277942551501 and parameters: {'n_estimators': 516, 'max_depth': 3, 'learning_rate': 0.006101335647747836, 'subsample': 0.6461202668426753, 'colsample_bytree': 0.78948147419495, 'num_leaves': 123}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:33:33,528] Trial 76 finished with value: 0.8598091752712064 and parameters: {'n_estimators': 458, 'max_depth': 3, 'learning_rate': 0.005310607764606442, 'subsample': 0.6722105196034266, 'colsample_bytree': 0.8829788668355805, 'num_leaves': 115}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:33:37,217] Trial 77 finished with value: 0.8534042809889104 and parameters: {'n_estimators': 586, 'max_depth': 5, 'learning_rate': 0.005484864042991998, 'subsample': 0.5947451162308097, 'colsample_bytree': 0.9127988062109285, 'num_leaves': 130}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:33:39,352] Trial 78 finished with value: 0.8592607301207483 and parameters: {'n_estimators': 457, 'max_depth': 4, 'learning_rate': 0.006731388521660227, 'subsample': 0.6745683587924515, 'colsample_bytree': 0.9057022478199889, 'num_leaves': 88}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:33:40,235] Trial 79 finished with value: 0.8598091752712064 and parameters: {'n_estimators': 379, 'max_depth': 3, 'learning_rate': 0.00760759854428353, 'subsample': 0.6133085042684692, 'colsample_bytree': 0.8757886573204767, 'num_leaves': 116}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:33:41,546] Trial 80 finished with value: 0.8592605625542495 and parameters: {'n_estimators': 369, 'max_depth': 4, 'learning_rate': 0.0077233794479974124, 'subsample': 0.702327323913797, 'colsample_bytree': 0.8581959006022546, 'num_leaves': 136}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:33:42,772] Trial 81 finished with value: 0.8594430424714046 and parameters: {'n_estimators': 401, 'max_depth': 3, 'learning_rate': 0.006206891634256061, 'subsample': 0.6098880438614456, 'colsample_bytree': 0.8795077008709815, 'num_leaves': 117}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:33:44,702] Trial 82 finished with value: 0.8587107768718016 and parameters: {'n_estimators': 544, 'max_depth': 3, 'learning_rate': 0.005422880677894172, 'subsample': 0.6411808230567235, 'colsample_bytree': 0.9160799296242277, 'num_leaves': 108}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:33:45,503] Trial 83 finished with value: 0.8596260250880562 and parameters: {'n_estimators': 328, 'max_depth': 3, 'learning_rate': 0.006065852825836023, 'subsample': 0.9925575300327343, 'colsample_bytree': 0.8546357538628887, 'num_leaves': 115}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:33:46,891] Trial 84 finished with value: 0.8596260250880562 and parameters: {'n_estimators': 461, 'max_depth': 3, 'learning_rate': 0.006868510367485741, 'subsample': 0.6172600265135344, 'colsample_bytree': 0.927834529762666, 'num_leaves': 95}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:33:48,521] Trial 85 finished with value: 0.8554160843730834 and parameters: {'n_estimators': 624, 'max_depth': 3, 'learning_rate': 0.008423080939044782, 'subsample': 0.5941903445897597, 'colsample_bytree': 0.8439749515237857, 'num_leaves': 121}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:33:53,278] Trial 86 finished with value: 0.8499274437060347 and parameters: {'n_estimators': 577, 'max_depth': 6, 'learning_rate': 0.0060452607924219096, 'subsample': 0.6636542386673717, 'colsample_bytree': 0.8082803259097066, 'num_leaves': 103}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:33:54,725] Trial 87 finished with value: 0.8598093428377052 and parameters: {'n_estimators': 278, 'max_depth': 4, 'learning_rate': 0.007460772891542707, 'subsample': 0.5806414224396066, 'colsample_bytree': 0.8701513793177205, 'num_leaves': 110}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:33:55,653] Trial 88 finished with value: 0.8603586258206569 and parameters: {'n_estimators': 266, 'max_depth': 4, 'learning_rate': 0.009203327757393857, 'subsample': 0.5590690361791976, 'colsample_bytree': 0.8871408045930143, 'num_leaves': 73}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:33:57,070] Trial 89 finished with value: 0.8554174249050736 and parameters: {'n_estimators': 264, 'max_depth': 5, 'learning_rate': 0.007351602735739879, 'subsample': 0.560652296869345, 'colsample_bytree': 0.8865700856346855, 'num_leaves': 75}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:33:58,477] Trial 90 finished with value: 0.8605412733043108 and parameters: {'n_estimators': 222, 'max_depth': 4, 'learning_rate': 0.009065089799669713, 'subsample': 0.6940884286040999, 'colsample_bytree': 0.8763797027129964, 'num_leaves': 71}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:33:59,341] Trial 91 finished with value: 0.8596265277875524 and parameters: {'n_estimators': 206, 'max_depth': 4, 'learning_rate': 0.014925722893558022, 'subsample': 0.6941754104663016, 'colsample_bytree': 0.8811573535015522, 'num_leaves': 65}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:34:00,700] Trial 92 finished with value: 0.8541363790220148 and parameters: {'n_estimators': 239, 'max_depth': 5, 'learning_rate': 0.009337755725945217, 'subsample': 0.6126286041385963, 'colsample_bytree': 0.9407884795987194, 'num_leaves': 71}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:34:02,101] Trial 93 finished with value: 0.859443545170901 and parameters: {'n_estimators': 295, 'max_depth': 4, 'learning_rate': 0.010226417567443299, 'subsample': 0.7292661718426579, 'colsample_bytree': 0.8979585441368021, 'num_leaves': 59}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:34:03,340] Trial 94 finished with value: 0.858528632087644 and parameters: {'n_estimators': 320, 'max_depth': 4, 'learning_rate': 0.00863054367703416, 'subsample': 0.6007975390883822, 'colsample_bytree': 0.843679418884764, 'num_leaves': 75}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:34:04,793] Trial 95 finished with value: 0.8526716802563097 and parameters: {'n_estimators': 360, 'max_depth': 4, 'learning_rate': 0.013234801446390842, 'subsample': 0.6614206167810963, 'colsample_bytree': 0.9518987776601845, 'num_leaves': 82}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:34:08,732] Trial 96 finished with value: 0.8499274437060347 and parameters: {'n_estimators': 264, 'max_depth': 8, 'learning_rate': 0.007663604991028579, 'subsample': 0.6399317831703574, 'colsample_bytree': 0.8707343922351117, 'num_leaves': 79}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:34:09,679] Trial 97 finished with value: 0.8596260250880562 and parameters: {'n_estimators': 400, 'max_depth': 3, 'learning_rate': 0.006650351354989957, 'subsample': 0.5801106110175794, 'colsample_bytree': 0.8946252634717377, 'num_leaves': 65}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:34:12,220] Trial 98 finished with value: 0.8528549980059588 and parameters: {'n_estimators': 429, 'max_depth': 5, 'learning_rate': 0.009248120528590259, 'subsample': 0.7048107399679135, 'colsample_bytree': 0.8721434288494627, 'num_leaves': 101}. Best is trial 68 with value: 0.8609064007051197.
# [I 2026-03-12 23:34:12,963] Trial 99 finished with value: 0.8596263602210538 and parameters: {'n_estimators': 323, 'max_depth': 3, 'learning_rate': 0.008113656935009254, 'subsample': 0.7375813752566962, 'colsample_bytree': 0.8446278044432968, 'num_leaves': 61}. Best is trial 68 with value: 0.8609064007051197.
# ✅ Best LightGBM Params: {'n_estimators': 500, 'max_depth': 3, 'learning_rate': 0.005349127354905027, 'subsample': 0.5992266054464054, 'colsample_bytree': 0.7037881072851143, 'num_leaves': 86}
#
# ⚙️ Training Final Stacked Model...

# %% [markdown]
# ### Meta-learner with Bias Control (Over-penalizing the model for missing Down-Trends)

# %%
# final_logic = LogisticRegression(C=0.1, class_weight={0: 1.5, 1: 1.0})

# %%
stack_model = StackingClassifier(estimators=base_models, final_estimator=final_logic, cv=5)
stack_model.fit(X_train_scaled, y_train)
y_probs = stack_model.predict_proba(X_test_scaled)[:, 1]
y_pred_aggressive = (stack_model.predict_proba(X_test_scaled)[:, 1] >= 0.45).astype(int)

# joblib.dump(stack_model, "EGX360_Quant_Model_V84.pkl")

# %% [markdown]
# ## 7. Final Evaluation & Down-Trend Accuracy

# %%
y_pred = stack_model.predict(X_test_scaled)
acc = accuracy_score(y_test, y_pred) * 100
print(f"\nDEEP QUANT ACCURACY: {acc:.2f}%")
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=['Down Trend (0)', 'Up Trend (1)']))

### Confusion Matrix Heatmap

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(7, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='RdYlGn', xticklabels=['Down', 'Up'], yticklabels=['Down', 'Up'], linewidths=1, linecolor='black')
plt.title(f"EGX360 Model V8.4\nDown-Trend Aware Accuracy: {acc:.2f}%\n(Risk-Adjusted Target)", fontsize=12, fontweight='bold')
plt.xlabel('Predicted Direction', fontsize=11)
plt.ylabel('Actual Direction', fontsize=11)
plt.show()
# Out:
# DEEP QUANT ACCURACY: 85.22%
#
# Classification Report:
#                 precision    recall  f1-score   support
#
# Down Trend (0)       0.81      0.80      0.80       512
#   Up Trend (1)       0.88      0.88      0.88       855
#
#       accuracy                           0.85      1367
#      macro avg       0.84      0.84      0.84      1367
#   weighted avg       0.85      0.85      0.85      1367

# %% [markdown]
# ## 8. Strategy Testing & Prediction Visualization (Signal Generation)
# **Concept:** Accuracy metrics and Confusion Matrices are abstract. To truly validate a Quantitative Model, we must map its predictions back onto the chronological price chart. Here, we visualize the model's output on the unseen test data.
# * **Green Up-Triangles:** The model predicted the $EMA_{10}$ will rise (Buy/Hold Signal).
# * **Red Down-Triangles:** The model predicted the $EMA_{10}$ will fall (Sell/Exit Signal).
#
# By observing these signals against the actual price action, we can visually confirm if the model successfully avoids "Whipsaws" (false signals) and accurately rides the major trends.

# %% [markdown]
# ### Create a DataFrame to map predictions back to dates and prices

# %%
# هنسحب التاريخ من الـ index ونعمله reset عشان يركب مع باقي الداتا بالمللي
test_dates = pd.Series(df.index[split:]).reset_index(drop=True)
test_close = df['close'].iloc[split:].reset_index(drop=True)
test_ema10 = df['close'].ewm(span=10).mean().iloc[split:].reset_index(drop=True)

# %%
results_df = pd.DataFrame({
    'timestamp': test_dates,
    'close': test_close,
    'EMA_10': test_ema10,
    'Actual_Trend': y_test,
    'Predicted_Trend': y_pred
})

# %% [markdown]
# ### To make the chart readable, we will visualize the last 150 days of the test set

# %%
viz_df = results_df.tail(150)

# %% [markdown]
# ### Create the Interactive Plotly Figure

# %%
fig_test = go.Figure()

# %% [markdown]
# ### 1. Plot the actual Close Price

# %%
fig_test.add_trace(go.Scatter(x=viz_df['timestamp'], y=viz_df['close'], 
                              mode='lines', name='Close Price', 
                              line=dict(color='rgba(128,128,128,0.5)', width=1.5)))

# %% [markdown]
# ### 2. Plot the Target (EMA 10)

# %%
fig_test.add_trace(go.Scatter(x=viz_df['timestamp'], y=viz_df['EMA_10'], 
                              mode='lines', name='EMA 10 (Target)', 
                              line=dict(color='blue', width=2)))

# %% [markdown]
# ### 3. Filter predictions for visualization

# %%
# 3. Filter predictions for visualization
buy_signals = viz_df[viz_df['Predicted_Trend'] == 1]
sell_signals = viz_df[viz_df['Predicted_Trend'] == 0]
results_df['Predicted_Trend'] = y_pred_aggressive
# أخذ نسب الثقة للاحتمال الإيجابي (Up Trend)
y_probs = stack_model.predict_proba(X_test_scaled)[:, 1]

# تحويل النسب لفئات تناسب مؤشرات الـ UI زي الصورة اللي بعتها
def get_signal_strength(prob):
    if prob >= 0.75:
        return 'Strong Buy'   # هيزيد أوي
    elif prob >= 0.55:
        return 'Buy'          # هيزيد عادي
    elif prob > 0.45:
        return 'Neutral'      # تذبذب / مش واضح
    elif prob > 0.25:
        return 'Sell'         # هيقل عادي
    else:
        return 'Strong Sell'  # هيقل أوي

# إضافة الفلتر للبيانات
results_df['Probability'] = y_probs
results_df['Filter_Signal'] = results_df['Probability'].apply(get_signal_strength)
# جلب إشارة اليوم لعرضها في الـ UI
latest_signal = results_df.iloc[-1]
print(f"Today's Signal: {latest_signal['Filter_Signal']} (Confidence: {latest_signal['Probability']:.2f})")
# Out:
# Today's Signal: Strong Sell (Confidence: 0.05)

# %% [markdown]
# ### 4. Plot Model Predictions (Up = Green, Down = Red)

# %%
fig_test.add_trace(go.Scatter(x=buy_signals['timestamp'], y=buy_signals['EMA_10'], 
                              mode='markers', name='Model Signal: UP (1)', 
                              marker=dict(color='green', symbol='triangle-up', size=12, line=dict(width=1, color='darkgreen'))))

fig_test.add_trace(go.Scatter(x=sell_signals['timestamp'], y=sell_signals['EMA_10'], 
                              mode='markers', name='Model Signal: DOWN (0)', 
                              marker=dict(color='red', symbol='triangle-down', size=12, line=dict(width=1, color='darkred'))))

# %% [markdown]
# # Formatting the Chart

# %%
fig_test.update_layout(title='EGX360 Live Signals: Model Predictions vs Actual Market (Test Set)',
                       yaxis_title='Price (EGP)',
                       xaxis_title='Date',
                       template='plotly_white',
                       hovermode='x unified')
fig_test.show()

# %% [markdown]
# ## 9. Strategy Backtesting & Financial Performance (ROI)
# **Concept:** A high predictive accuracy is only valuable if it translates into excess financial returns (Alpha). Here, we simulate a realistic trading environment starting with 10,000 EGP.
#
# **Backtesting Rules to Prevent Look-Ahead Bias:**
# 1. The model uses today's closing data to predict tomorrow's $EMA_{10}$ direction.
# 2. If the prediction is UP (1), we hold the asset for tomorrow.
# 3. If the prediction is DOWN (0), we sell at today's close and hold cash tomorrow (0% market return).
# 4. We compare our strategy's cumulative returns against a standard "Buy and Hold" baseline.

# %% [markdown]
# ## 1. Initial Setup

# %%
initial_capital = 10000.0

### Calculate actual daily percentage returns of the closing price
results_df['daily_return'] = results_df['close'].pct_change()
### CRITICAL: Shift the signal by 1 day to prevent look-ahead bias.
### If the model predicts '1' today, we are IN the market tomorrow.
results_df['signal'] = results_df['Predicted_Trend'].shift(1)
## 2. Strategy Return Calculation
### We only earn the daily return if our signal for that day was 1 (Hold). Otherwise, we earn 0 (Cash).

results_df['strategy_return'] = results_df['daily_return'] * results_df['signal']
### Drop the first row which will have NaNs due to shifting/pct_change

bt_df = results_df.dropna().copy()
## 3. Cumulative Returns
bt_df['cumulative_market'] = (1 + bt_df['daily_return']).cumprod()
bt_df['cumulative_strategy'] = (1 + bt_df['strategy_return']).cumprod()
## 4. Monetary Value Tracking
bt_df['portfolio_value'] = initial_capital * bt_df['cumulative_strategy']
bt_df['bh_value'] = initial_capital * bt_df['cumulative_market']

# %% [markdown]
# ## 5. Final Metrics & Visualizing the Portfolio Growth

# %%
final_portfolio = bt_df['portfolio_value'].iloc[-1]
final_bh = bt_df['bh_value'].iloc[-1]

strategy_profit_pct = ((final_portfolio - initial_capital) / initial_capital) * 100
market_profit_pct = ((final_bh - initial_capital) / initial_capital) * 100

print(f" Initial Capital: {initial_capital:,.2f} EGP")
print("-" * 40)
print(f"1) Buy & Hold Strategy (Market): {final_bh:,.2f} EGP ({market_profit_pct:.2f}%)")
print(f"2) EGX360 Strategy (Model):      {final_portfolio:,.2f} EGP ({strategy_profit_pct:.2f}%)")
print("-" * 40)
outperformance = strategy_profit_pct - market_profit_pct
print(f" The EGX360 Model outperformed the market by: {outperformance:.2f}%")

fig_bt = go.Figure()

# Plot Model Strategy Portfolio
fig_bt.add_trace(go.Scatter(x=bt_df['timestamp'], y=bt_df['portfolio_value'], 
                            mode='lines', name='EGX360 Strategy', 
                            line=dict(color='green', width=2.5)))

# Plot Buy & Hold Portfolio
fig_bt.add_trace(go.Scatter(x=bt_df['timestamp'], y=bt_df['bh_value'], 
                            mode='lines', name='Buy & Hold Baseline', 
                            line=dict(color='gray', width=1.5, dash='dash')))

fig_bt.update_layout(title='EGX360 Financial Backtest: Portfolio Growth (10,000 EGP Initial)',
                     yaxis_title='Portfolio Value (EGP)',
                     xaxis_title='Date',
                     template='plotly_white',
                     hovermode='x unified')
fig_bt.show()
# Out:
#  Initial Capital: 10,000.00 EGP
# ----------------------------------------
# 1) Buy & Hold Strategy (Market): 42,433.67 EGP (324.34%)
# 2) EGX360 Strategy (Model):      58,342.31 EGP (483.42%)
# ----------------------------------------
#  The EGX360 Model outperformed the market by: 159.09%
